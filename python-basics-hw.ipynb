# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
len(long_phrase)>len(short_phrase)

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
size_fileB=int(input('введите размер файла в байтах: '))
size_fileMB=size_fileB/1000000
print('Объем файла равен',size_fileMB,'Mb')

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
месяц=input('введите месяц: ')
число=int(input('введите число: '))
if (месяц =='март' and число>=21) or (месяц =='апрель' and число<=20):
    print('Овен')
elif (месяц =='апрель' and число>=21) or (месяц =='май' and число<=20):
    print('Телец')
elif (месяц =='май' and число>=21) or (месяц =='июнь' and число<=21):
    print('Близнецы')
elif (месяц =='июнь' and число>=22) or (месяц =='июль' and число<=22):
    print('Рак')
elif (месяц =='июль' and число>=23) or (месяц =='август' and число<=23):
    print('Лев')
elif (месяц =='август' and число>=24) or (месяц =='сентябрь' and число<=23):
    print('Дева')
elif (месяц =='сентябрь' and число>=24) or (месяц =='октябрь' and число<=23):
    print('Весы')
elif (месяц =='октябрь' and число>=24) or (месяц =='ноябрь' and число<=22):
    print('Скорпион')
elif (месяц =='ноябрь' and число>=23) or (месяц =='декабрь' and число<=21):
    print('Стрелец')
elif (месяц =='декабрь' and число>=22) or (месяц =='январь' and число<=20):
    print('Козерог')
elif (месяц =='январь' and число>=21) or (месяц =='февраль' and число<=18):
    print('Водолей')
else:
    print('Рыбы')

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
заработная_плата_в_месяц=int(input('Введите заработанную плату в месяц: '))
проценты_от_ЗП_на_ипотеку=int(input('Введите сколько процентов уходит на ипотеку: '))
проценты_от_ЗП_на_жизнь=int(input('Введите сколько процентов уходит на жизнь: '))
количество_премий_в_год=int(input('Введите количество премий за год: '))
ипотека=int(заработная_плата_в_месяц*12*(проценты_от_ЗП_на_ипотеку/100))
накоплено=int((100-проценты_от_ЗП_на_жизнь-проценты_от_ЗП_на_ипотеку)/100*\
заработная_плата_в_месяц*12+количество_премий_в_год*заработная_плата_в_месяц*0.5)
print('Вывод:','На ипотеку было потрачено:',ипотека,'рублей','Было накоплено:',\
     накоплено,'рублей')
